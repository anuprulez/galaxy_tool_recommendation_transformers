# %%
import pandas as pd

wf_path = "data/aug_22/workflow-connections_Aug_22.csv"
tp_path = "data/aug_22/tool_popularity_Aug_22.csv"

# %%
wf = pd.read_csv(wf_path, sep="|")
# Out:
# /tmp/ipykernel_28439/3503387345.py:1: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   wf = pd.read_csv(wf_path, sep="|")

# %%
wf
# Out:
#                                                    wf_id     wf_updated   \
# 0        --------+------------+---------+--------------...           NaN
# 1                                                       3    2013-02-07
# 2                                                       3    2013-02-07
# 3                                                       3    2013-02-07
# 4                                                       3    2013-02-07
# ...                                                    ...           ...
# 2980811                                            157077    2022-08-08
# 2980812                                            157077    2022-08-08
# 2980813                                            157077    2022-08-08
# 2980814                                            157077    2022-08-08
# 2980815                                     (2980814 rows)           NaN
#
#            in_id    \
# 0              NaN
# 1              5.0
# 2              6.0
# 3              7.0
# 4              7.0
# ...            ...
# 2980811  2419707.0
# 2980812  2419707.0
# 2980813  2419708.0
# 2980814  2419708.0
# 2980815        NaN
#
#                                                                         in_tool                                                                   \
# 0                                                      NaN
# 1         Grep1                                        ...
# 2         Cut1                                         ...
# 3         Remove beginning1                            ...
# 4         Remove beginning1                            ...
# ...                                                    ...
# 2980811   toolshed.g2.bx.psu.edu/repos/iuc/unicycler/un...
# 2980812   toolshed.g2.bx.psu.edu/repos/iuc/unicycler/un...
# 2980813   toolshed.g2.bx.psu.edu/repos/nml/spades/spade...
# 2980814   toolshed.g2.bx.psu.edu/repos/nml/spades/spade...
# 2980815                                                NaN
#
#                            in_tool_v                      out_id    \
# 0                                                   NaN        NaN
# 1         1.0.1                                                7.0
# 2         1.0.1                                                8.0
# 3         1.0.0                                                6.0
# 4         1.0.0                                                9.0
# ...                                                 ...        ...
# 2980811   0.4.6.0                                        2419709.0
# 2980812   0.4.6.0                                        2419710.0
# 2980813   3.12.0+galaxy1                                 2419711.0
# 2980814   3.12.0+galaxy1                                 2419712.0
# 2980815                                             NaN        NaN
#
#                                                                         out_tool                                                                  \
# 0                                                      NaN
# 1         Remove beginning1                            ...
# 2         addValue                                     ...
# 3         Cut1                                         ...
# 4         Cut1                                         ...
# ...                                                    ...
# 2980811   toolshed.g2.bx.psu.edu/repos/iuc/bandage/band...
# 2980812   toolshed.g2.bx.psu.edu/repos/iuc/bandage/band...
# 2980813   toolshed.g2.bx.psu.edu/repos/iuc/bandage/band...
# 2980814   toolshed.g2.bx.psu.edu/repos/iuc/bandage/band...
# 2980815                                                NaN
#
#                            out_tool_v                     published   \
# 0                                                   NaN          NaN
# 1         1.0.0                                           f
# 2         1.0.0                                           f
# 3         1.0.1                                           f
# 4         1.0.1                                           f
# ...                                                 ...          ...
# 2980811   0.8.1+galaxy1                                   f
# 2980812   0.8.1+galaxy2                                   f
# 2980813   0.8.1+galaxy2                                   f
# 2980814   0.8.1+galaxy1                                   f
# 2980815                                             NaN          NaN
#
#           deleted   has_errors
# 0              NaN          NaN
# 1         t                   f
# 2         t                   f
# 3         t                   f
# 4         t                   f
# ...            ...          ...
# 2980811   f                   f
# 2980812   f                   f
# 2980813   f                   f
# 2980814   f                   f
# 2980815        NaN          NaN
#
# [2980816 rows x 11 columns]

# %%
wf_fil_tail = wf.tail(1000)
wf_fil_head = wf.head(1000)
wf_fil = pd.concat([wf_fil_head, wf_fil_tail])
wf_fil
# Out:
#                                                    wf_id     wf_updated   \
# 0        --------+------------+---------+--------------...           NaN
# 1                                                       3    2013-02-07
# 2                                                       3    2013-02-07
# 3                                                       3    2013-02-07
# 4                                                       3    2013-02-07
# ...                                                    ...           ...
# 2980811                                            157077    2022-08-08
# 2980812                                            157077    2022-08-08
# 2980813                                            157077    2022-08-08
# 2980814                                            157077    2022-08-08
# 2980815                                     (2980814 rows)           NaN
#
#            in_id    \
# 0              NaN
# 1              5.0
# 2              6.0
# 3              7.0
# 4              7.0
# ...            ...
# 2980811  2419707.0
# 2980812  2419707.0
# 2980813  2419708.0
# 2980814  2419708.0
# 2980815        NaN
#
#                                                                         in_tool                                                                   \
# 0                                                      NaN
# 1         Grep1                                        ...
# 2         Cut1                                         ...
# 3         Remove beginning1                            ...
# 4         Remove beginning1                            ...
# ...                                                    ...
# 2980811   toolshed.g2.bx.psu.edu/repos/iuc/unicycler/un...
# 2980812   toolshed.g2.bx.psu.edu/repos/iuc/unicycler/un...
# 2980813   toolshed.g2.bx.psu.edu/repos/nml/spades/spade...
# 2980814   toolshed.g2.bx.psu.edu/repos/nml/spades/spade...
# 2980815                                                NaN
#
#                            in_tool_v                      out_id    \
# 0                                                   NaN        NaN
# 1         1.0.1                                                7.0
# 2         1.0.1                                                8.0
# 3         1.0.0                                                6.0
# 4         1.0.0                                                9.0
# ...                                                 ...        ...
# 2980811   0.4.6.0                                        2419709.0
# 2980812   0.4.6.0                                        2419710.0
# 2980813   3.12.0+galaxy1                                 2419711.0
# 2980814   3.12.0+galaxy1                                 2419712.0
# 2980815                                             NaN        NaN
#
#                                                                         out_tool                                                                  \
# 0                                                      NaN
# 1         Remove beginning1                            ...
# 2         addValue                                     ...
# 3         Cut1                                         ...
# 4         Cut1                                         ...
# ...                                                    ...
# 2980811   toolshed.g2.bx.psu.edu/repos/iuc/bandage/band...
# 2980812   toolshed.g2.bx.psu.edu/repos/iuc/bandage/band...
# 2980813   toolshed.g2.bx.psu.edu/repos/iuc/bandage/band...
# 2980814   toolshed.g2.bx.psu.edu/repos/iuc/bandage/band...
# 2980815                                                NaN
#
#                            out_tool_v                     published   \
# 0                                                   NaN          NaN
# 1         1.0.0                                           f
# 2         1.0.0                                           f
# 3         1.0.1                                           f
# 4         1.0.1                                           f
# ...                                                 ...          ...
# 2980811   0.8.1+galaxy1                                   f
# 2980812   0.8.1+galaxy2                                   f
# 2980813   0.8.1+galaxy2                                   f
# 2980814   0.8.1+galaxy1                                   f
# 2980815                                             NaN          NaN
#
#           deleted   has_errors
# 0              NaN          NaN
# 1         t                   f
# 2         t                   f
# 3         t                   f
# 4         t                   f
# ...            ...          ...
# 2980811   f                   f
# 2980812   f                   f
# 2980813   f                   f
# 2980814   f                   f
# 2980815        NaN          NaN
#
# [2000 rows x 11 columns]

# %%
wf_fil.to_csv("data/aug_22/wf-subset.csv", index=None, sep="|")
