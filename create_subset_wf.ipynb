# %%
import pandas as pd

wf_path = "data/aug_22/workflow-connections_Aug_22.csv"
tp_path = "data/aug_22/tool_popularity_Aug_22.csv"

# %%
wf = pd.read_csv(wf_path, sep="|")
# Out:
# /tmp/ipykernel_681767/3503387345.py:1: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   wf = pd.read_csv(wf_path, sep="|")

# %%
wf
# Out:
#                                                    wf_id     wf_updated   \
# 0        --------+------------+---------+--------------...           NaN
# 1                                                       3    2013-02-07
# 2                                                       3    2013-02-07
# 3                                                       3    2013-02-07
# 4                                                       3    2013-02-07
# ...                                                    ...           ...
# 2980811                                            157077    2022-08-08
# 2980812                                            157077    2022-08-08
# 2980813                                            157077    2022-08-08
# 2980814                                            157077    2022-08-08
# 2980815                                     (2980814 rows)           NaN
#
#            in_id    \
# 0              NaN
# 1              5.0
# 2              6.0
# ...

# %%
wf_fil_head = wf.head(100)
wf_fil_tail = wf.tail(1000)
wf_fil = pd.concat([wf_fil_head, wf_fil_tail])
wf_fil
# Out:
#                                                    wf_id     wf_updated   \
# 0        --------+------------+---------+--------------...           NaN
# 1                                                       3    2013-02-07
# 2                                                       3    2013-02-07
# 3                                                       3    2013-02-07
# 4                                                       3    2013-02-07
# ...                                                    ...           ...
# 2980811                                            157077    2022-08-08
# 2980812                                            157077    2022-08-08
# 2980813                                            157077    2022-08-08
# 2980814                                            157077    2022-08-08
# 2980815                                     (2980814 rows)           NaN
#
#            in_id    \
# 0              NaN
# 1              5.0
# 2              6.0
# ...

# %%
wf_fil.to_csv("data/aug_22/wf-subset.csv", index=None, sep="|")

# %%
tp = pd.read_csv(tp_path, sep="|")

# %%
tp_fil_head = tp.head(1000)
tp_fil_tail = tp.tail(1000)
tp_fil = pd.concat([tp_fil_head, tp_fil_tail])
tp_fil
# Out:
#                                                                              tool_id                                                                         \
# 0      ----------------------------------------------...
# 1       toolshed.g2.bx.psu.edu/repos/bgruening/sdf_to...
# 2       __DATA_FETCH__                               ...
# 3       toolshed.g2.bx.psu.edu/repos/devteam/fastqc/f...
# 4       toolshed.g2.bx.psu.edu/repos/iuc/snpsift/snpS...
# ...                                                  ...
# 51298   toolshed.g2.bx.psu.edu/repos/iuc/ngsutils_bam...
# 51299   toolshed.g2.bx.psu.edu/repos/devteam/fastqtof...
# 51300   toolshed.g2.bx.psu.edu/repos/earlhaminst/ense...
# 51301   toolshed.g2.bx.psu.edu/repos/bgruening/rxdock...
# 51302                                       (51301 rows)
#
#           month       count
# 0               NaN       NaN
# 1       2022-09-01    63928.0
# 2       2022-09-01    32104.0
# 3       2022-09-01     6885.0
# ...

# %%
tp_fil.to_csv("data/aug_22/tp-subset.csv", index=None, sep="|")
